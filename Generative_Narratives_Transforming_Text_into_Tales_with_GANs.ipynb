# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Function to generate story based on user input prompt
def generate_story(prompt, max_length=500, temperature=0.9):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    attention_mask = torch.ones(input_ids.shape, dtype=torch.long)
    pad_token_id = tokenizer.eos_token_id
    output = model.generate(input_ids, max_length=max_length, temperature=temperature, num_return_sequences=1, attention_mask=attention_mask, pad_token_id=pad_token_id, do_sample=True)
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# Main function to interact with the user and generate stories
def main():
    print("Welcome to the Story Generator!")
    while True:
        user_prompt = input("Enter a prompt to start the story (or 'quit' to exit): ")
        if user_prompt.lower() == 'quit':
            print("Exiting...")
            break
        else:
            story = generate_story(user_prompt, temperature=0.7)
            print("\nGenerated Story:")
            print(story)
            print("\nApproximate Word Count:", len(story.split()))
            print("\n")

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Welcome to the Story Generator!
# Enter a prompt to start the story (or 'quit' to exit): london bridge is fallind down
#
# Generated Story:
# london bridge is fallind down the road from the Gervais. The Gervais bridge is a popular attraction to fans of the film The Lion King, especially those who like to travel through the Alps.
#
# I was able to get to the Gervais bridge and walk to the other side of the gorge.
#
# While I wasn't able to get to the bridge, I was able to get to the next section of the bridge.
#
# I decided that I could walk around the gorge.
#
# I was able to walk around the bridge and walk around the gorge and I found some hidden gems.
#
# In the pictures below:
#
# From above, you can see two hidden gems from above.
#
# The top of the gorge is very clear and you can see that there are two things on it. The first thing is that there is a big bridge on the right side and the second thing is that there is a huge bridge on the bottom of the gorge.
#
# The Gervais bridge is very clear and you can see that there are two things on the top of the gorge.
#
# The first thing is a huge bridge on the right side which is actually a long bridge. The second thing is that there is a huge bridge on the bottom of the gorge.
#
# The bridge on the right side is also a long bridge.
#
# There is a huge staircase leading up to the Gervais bridge.
#
# The staircase leads to the Gervais bridge.
#
# The bridge on the bottom of the gorge is quite clear and there is a staircase on the right side which leads up to the bridge.
#
# The bridge on the bottom of the gorge is a very narrow staircase and there is a long staircase on the bottom of the gorge.
#
# The top of the gorge is an amazing view.
#
# The top of the gorge is very clear and there is a huge staircase on the right side which leads up to the bridge.
#
# The bridge on the bottom of the gorge is a very narrow staircase and there is a long staircase on the bottom of the gorge.
#
# The top of the gorge is truly breathtaking.
#
# The right side of the bridge is very clear and you can see a huge view of the gorge.
#
# The bridge on the bottom of the gorge is a very narrow staircase and there is a long staircase on the bottom of the gorge.
#
# The bridge on the bottom of the
#
# Approximate Word Count: 416
#
#
# Enter a prompt to start the story (or 'quit' to exit): quit
# Exiting...
